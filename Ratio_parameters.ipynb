# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy as sp
import csv
import matplotlib.patches as mpatches
import pylab as pb
import matplotlib.ticker as mtick
from matplotlib import cm
from numpy import linspace
from csv import reader
import matplotlib.colors as colors
import matplotlib.ticker as ticker
import seaborn as sns
import pandas as pd
from IPython.display import Image, display
from scipy.stats import norm
import matplotlib.mlab as mlab
from scipy.stats import linregress

# %%
data = pd.read_csv("Ratio_parameters.csv")
sample = data["Sample"]
true_channel = data["True area of channel"]
true_cut = data["True area of cut"]
true_ratio = data["True ratio"]
large_elec = data["Large electrode width"]
small_elec = data["Small electrode width"]
elec_ratio = data["Electrode ratio"]
overshoot = data["Overshoot"]
elec_cut = data["Electrode cut"]
GBs = data["GBs"]
ratio_60 = data["Ratio at -60"]
sat_ratio = data["Saturation ratio"]
max_ratio = data["Max ratio"]
min_ratio = data["Min ratio"]
Vth = data["Delta Vth"]
pos_vset = data["Positive Vset"]
neg_vset = data["Negative Vset"]
pos_states = data["Positive HRS/LRS"]
neg_states = data["Negative HRS/LRS"]

# %%
###data for ratio IVs tested in EVO at 35 Volt sweep
data_0001_EVO = pd.read_csv("Chip 1/X_M/IVs/0001_35V_sweep_EVO.csv")
x_0001_EVO = data_0001_EVO["CH1 Voltage"]
y_0001_EVO = data_0001_EVO["CH1 Current"]

#data_015_air = pd.read_csv("Chip 1/X_M/IVs/015_35V_sweep_air.csv")
#x_015_air = data["CH1 Voltage"]
#y_015_air = data["CH1 Current"]

data_02_EVO = pd.read_csv("Chip 2/W_B/IVs/02_35V_sweep_EVO.csv")
x_02_EVO = data_02_EVO["CH1 Voltage"]
y_02_EVO = data_02_EVO["CH1 Current"]

data_025_EVO = pd.read_csv("Chip 1/X_M/IVs/025_35V_sweep_EVO.csv")
x_025_EVO= data_025_EVO["CH1 Voltage"]
y_025_EVO = data_025_EVO["CH1 Current"]

data_03_EVO = pd.read_csv("Chip 2/Z_A/IVs/03_35V_sweep_EVO.csv")
x_03_EVO = data_03_EVO["CH1 Voltage"]
y_03_EVO = data_03_EVO["CH1 Current"]

#data_035_EVO = pd.read_csv("Chip 2/R_A/IVs/035_35V_sweep_EVO.csv")
#x_035_EVO = data_035_EVO["CH1 Voltage"]
#y_035_EVO = data_035_EVO["CH1 Current"]

data_04_EVO = pd.read_csv("Chip 2/W_B/IVs/04_35V_sweep_EVO.csv")
x_04_EVO = data_04_EVO["CH1 Voltage"]
y_04_EVO = data_04_EVO["CH1 Current"]

data_045_EVO = pd.read_csv("Chip 2/R_A/IVs/045_35V_sweep_EVO.csv")
x_045_EVO = data_045_EVO["CH1 Voltage"]
y_045_EVO = data_045_EVO["CH1 Current"]

data_05_EVO = pd.read_csv("Chip 2/Z_A/IVs/05_35V_sweep_EVO.csv")
x_05_EVO = data_05_EVO["CH1 Voltage"]
y_05_EVO = data_05_EVO["CH1 Current"]

data_055_EVO = pd.read_csv("Chip 2/R_A/IVs/055_35V_sweep_EVO.csv")
x_055_EVO = data_055_EVO["CH1 Voltage"]
y_055_EVO = data_055_EVO["CH1 Current"]

data_06_EVO = pd.read_csv("Chip 1/V_K/IVs/06_35V_sweep_EVO.csv")
x_06_EVO = data_06_EVO["CH1 Voltage"]
y_06_EVO = data_06_EVO["CH1 Current"]

data_065_EVO = pd.read_csv("Chip 2/T_A/IVs/065_35V_sweep_EVO.csv")
x_065_EVO = data_065_EVO["CH1 Voltage"]
y_065_EVO = data_065_EVO["CH1 Current"]

data_07_EVO = pd.read_csv("Chip 1/V_K/IVs/07_35V_sweep_EVO.csv")
x_07_EVO = data_07_EVO["CH1 Voltage"]
y_07_EVO = data_07_EVO["CH1 Current"]

data_075_EVO = pd.read_csv("Chip 2/T_A/IVs/075_35V_sweep_EVO.csv")
x_075_EVO = data_075_EVO["CH1 Voltage"]
y_075_EVO = data_075_EVO["CH1 Current"]

data_08_EVO = pd.read_csv("Chip 1/V_K/IVs/08_35V_sweep_EVO.csv")
x_08_EVO = data_08_EVO["CH1 Voltage"]
y_08_EVO = data_08_EVO["CH1 Current"]

data_085_EVO = pd.read_csv("Chip 2/T_A/IVs/085_35V_sweep_EVO.csv")
x_085_EVO = data_085_EVO["CH1 Voltage"]
y_085_EVO = data_085_EVO["CH1 Current"]

#data_09_air = pd.read_csv("Chip 1/W_L/IVs/09_35V_sweep_air.csv")
#x_09_air = data["CH1 Voltage"]
#y_09_air = data["CH1 Current"]

data_095_EVO = pd.read_csv("Chip 2/W_B/IVs/095_35V_sweep_EVO.csv")
x_095_EVO = data_095_EVO["CH1 Voltage"]
y_095_EVO = data_095_EVO["CH1 Current"]

data_10_EVO = pd.read_csv("Chip 1/W_L/IVs/10_35V_sweep_EVO.csv")
x_10_EVO = data_10_EVO["CH1 Voltage"]
y_10_EVO = data_10_EVO["CH1 Current"]

### Data for ratio IVs tested in EVO at 5 Volt sweep
data_0001_EVO_5 = pd.read_csv("Chip 2/W_B/IVs/02_5V_sweep_EVO.csv")
x_0001_EVO_5 = data_0001_EVO_5["CH1 Voltage"]
y_0001_EVO_5 = data_0001_EVO_5["CH1 Current"]

#data_015_air = pd.read_csv("Chip 1/X_M/IVs/015_35V_sweep_air.csv")
#x_015_air = data["CH1 Voltage"]
#y_015_air = data["CH1 Current"]

data_02_EVO_5 = pd.read_csv("Chip 2/W_B/IVs/02_5V_sweep_EVO.csv")
x_02_EVO_5 = data_02_EVO_5["CH1 Voltage"]
y_02_EVO_5 = data_02_EVO_5["CH1 Current"]

data_025_EVO_5 = pd.read_csv("Chip 1/X_M/IVs/025_5V_sweep_EVO.csv")
x_025_EVO_5 = data_025_EVO_5["CH1 Voltage"]
y_025_EVO_5 = data_025_EVO_5["CH1 Current"]

data_03_EVO_5 = pd.read_csv("Chip 2/Z_A/IVs/03_5V_sweep_EVO.csv")
x_03_EVO_5 = data_03_EVO_5["CH1 Voltage"]
y_03_EVO_5 = data_03_EVO_5["CH1 Current"]

#data_035_EVO_5 = pd.read_csv("Chip 2/R_A/IVs/035_5V_sweep_EVO.csv")
#x_035_EVO_5 = data_035_EVO_5["CH1 Voltage"]
#y_035_EVO_5 = data_035_EVO_5["CH1 Current"]

data_04_EVO_5 = pd.read_csv("Chip 2/W_B/IVs/04_5V_sweep_EVO.csv")
x_04_EVO_5 = data_04_EVO_5["CH1 Voltage"]
y_04_EVO_5 = data_04_EVO_5["CH1 Current"]

data_045_EVO_5 = pd.read_csv("Chip 2/R_A/IVs/045_5V_sweep_EVO.csv")
x_045_EVO_5 = data_045_EVO_5["CH1 Voltage"]
y_045_EVO_5 = data_045_EVO_5["CH1 Current"]

data_05_EVO_5 = pd.read_csv("Chip 2/Z_A/IVs/05_5V_sweep_EVO.csv")
x_05_EVO_5 = data_05_EVO_5["CH1 Voltage"]
y_05_EVO_5 = data_05_EVO_5["CH1 Current"]

data_055_EVO_5 = pd.read_csv("Chip 2/R_A/IVs/055_5V_sweep_EVO.csv")
x_055_EVO_5 = data_055_EVO_5["CH1 Voltage"]
y_055_EVO_5 = data_055_EVO_5["CH1 Current"]

data_06_EVO_5 = pd.read_csv("Chip 1/V_K/IVs/06_5V_sweep_EVO.csv")
x_06_EVO_5 = data_06_EVO_5["CH1 Voltage"]
y_06_EVO_5 = data_06_EVO_5["CH1 Current"]

data_065_EVO_5 = pd.read_csv("Chip 2/T_A/IVs/065_5V_sweep_EVO.csv")
x_065_EVO_5 = data_065_EVO_5["CH1 Voltage"]
y_065_EVO_5 = data_065_EVO_5["CH1 Current"]

data_07_EVO_5 = pd.read_csv("Chip 1/V_K/IVs/07_5V_sweep_EVO.csv")
x_07_EVO_5 = data_07_EVO_5["CH1 Voltage"]
y_07_EVO_5 = data_07_EVO_5["CH1 Current"]

data_075_EVO_5 = pd.read_csv("Chip 2/T_A/IVs/075_5V_sweep_EVO.csv")
x_075_EVO_5 = data_075_EVO_5["CH1 Voltage"]
y_075_EVO_5 = data_075_EVO_5["CH1 Current"]

data_08_EVO_5 = pd.read_csv("Chip 1/V_K/IVs/08_5V_sweep_EVO.csv")
x_08_EVO_5 = data_08_EVO_5["CH1 Voltage"]
y_08_EVO_5 = data_08_EVO_5["CH1 Current"]

data_085_EVO_5 = pd.read_csv("Chip 2/T_A/IVs/085_5V_sweep_EVO.csv")
x_085_EVO_5 = data_085_EVO_5["CH1 Voltage"]
y_085_EVO_5 = data_085_EVO_5["CH1 Current"]

#data_09_air = pd.read_csv("Chip 1/W_L/IVs/09_35V_sweep_air.csv")
#x_09_air = data["CH1 Voltage"]
#y_09_air = data["CH1 Current"]

data_095_EVO_5 = pd.read_csv("Chip 2/W_B/IVs/095_5V_sweep_EVO.csv")
x_095_EVO_5 = data_095_EVO_5["CH1 Voltage"]
y_095_EVO_5 = data_095_EVO_5["CH1 Current"]

data_10_EVO_5 = pd.read_csv("Chip 1/W_L/IVs/10_5V_sweep_EVO.csv")
x_10_EVO_5 = data_10_EVO_5["CH1 Voltage"]
y_10_EVO_5 = data_10_EVO_5["CH1 Current"]

### Data for ratio gate sweeps in EVO
data_0001_EVO_gt = pd.read_csv("Chip 1/X_M/Gates/0001_gate_sweep_EVO.csv")
x_0001_EVO_gt = data_0001_EVO_gt["CH2 Voltage"]
y_0001_EVO_gt = data_0001_EVO_gt["CH1 Current"]

#data_015_air_gt = pd.read_csv("Chip 1/X_M/Gates/015_gate_sweep_air.csv")
#x_015_air_gt = data["CH2 Voltage"]
#y_015_air_gt = data["CH1 Current"]

data_02_EVO_gt = pd.read_csv("Chip 2/W_B/Gates/02_gate_sweep_EVO.csv")
x_02_EVO_gt = data_02_EVO_gt["CH2 Voltage"]
y_02_EVO_gt = data_02_EVO_gt["CH1 Current"]

data_025_EVO_gt = pd.read_csv("Chip 1/X_M/Gates/025_gate_sweep_EVO.csv")
x_025_EVO_gt = data_025_EVO_gt["CH2 Voltage"]
y_025_EVO_gt = data_025_EVO_gt["CH1 Current"]

data_03_EVO_gt = pd.read_csv("Chip 2/Z_A/Gates/03_gate_sweep_EVO.csv")
x_03_EVO_gt = data_03_EVO_gt["CH2 Voltage"]
y_03_EVO_gt = data_03_EVO_gt["CH1 Current"]

#data_035_EVO_gt = pd.read_csv("Chip 2/R_A/Gates/035_gate_sweep_EVO.csv")
#x_035_EVO_gt = data_035_EVO_gt["CH2 Voltage"]
#y_035_EVO_gt = data_035_EVO_gt["CH1 Current"]

data_04_EVO_gt = pd.read_csv("Chip 2/W_B/Gates/04_gate_sweep_EVO.csv")
x_04_EVO_gt = data_04_EVO_gt["CH2 Voltage"]
y_04_EVO_gt = data_04_EVO_gt["CH1 Current"]

data_045_EVO_gt = pd.read_csv("Chip 2/R_A/Gates/045_gate_sweep_EVO.csv")
x_045_EVO_gt = data_045_EVO_gt["CH2 Voltage"]
y_045_EVO_gt = data_045_EVO_gt["CH1 Current"]

data_05_EVO_gt = pd.read_csv("Chip 2/Z_A/Gates/05_gate_sweep_EVO.csv")
x_05_EVO_gt = data_05_EVO_gt["CH2 Voltage"]
y_05_EVO_gt = data_05_EVO_gt["CH1 Current"]

data_055_EVO_gt = pd.read_csv("Chip 2/R_A/Gates/055_gate_sweep_EVO.csv")
x_055_EVO_gt = data_055_EVO_gt ["CH2 Voltage"]
y_055_EVO_gt = data_055_EVO_gt ["CH1 Current"]

data_06_EVO_gt = pd.read_csv("Chip 1/V_K/Gates/06_gate_sweep_EVO.csv")
x_06_EVO_gt = data_06_EVO_gt["CH2 Voltage"]
y_06_EVO_gt = data_06_EVO_gt["CH1 Current"]

data_065_EVO_gt = pd.read_csv("Chip 2/T_A/Gates/065_gate_sweep_EVO.csv")
x_065_EVO_gt = data_065_EVO_gt["CH2 Voltage"]
y_065_EVO_gt = data_065_EVO_gt["CH1 Current"]

data_07_EVO_gt = pd.read_csv("Chip 1/V_K/Gates/07_gate_sweep_EVO.csv")
x_07_EVO_gt = data_07_EVO_gt["CH2 Voltage"]
y_07_EVO_gt = data_07_EVO_gt["CH1 Current"]

data_075_EVO_gt = pd.read_csv("Chip 2/T_A/Gates/075_gate_sweep_EVO.csv")
x_075_EVO_gt = data_075_EVO_gt["CH2 Voltage"]
y_075_EVO_gt = data_075_EVO_gt["CH1 Current"]

data_08_EVO_gt = pd.read_csv("Chip 1/V_K/Gates/08_gate_sweep_EVO.csv")
x_08_EVO_gt = data_08_EVO_gt["CH2 Voltage"]
y_08_EVO_gt = data_08_EVO_gt["CH1 Current"]

data_085_EVO_gt = pd.read_csv("Chip 2/T_A/Gates/085_gate_sweep_EVO.csv")
x_085_EVO_gt = data_085_EVO_gt["CH2 Voltage"]
y_085_EVO_gt = data_085_EVO_gt["CH1 Current"]

#data_09_air_gt = pd.read_csv("Chip 1/W_L/Gates/09_gate_sweep_air.csv")
#x_09_air_gt = data["CH2 Voltage"]
#y_09_air_gt = data["CH1 Current"]

data_095_EVO_gt = pd.read_csv("Chip 2/W_B/Gates/095_gate_sweep_EVO.csv")
x_095_EVO_gt = data_095_EVO_gt["CH2 Voltage"]
y_095_EVO_gt = data_095_EVO_gt["CH1 Current"]

data_10_EVO_gt = pd.read_csv("Chip 1/W_L/Gates/10_gate_sweep_EVO.csv")
x_10_EVO_gt = data_10_EVO_gt["CH2 Voltage"]
y_10_EVO_gt = data_10_EVO_gt["CH1 Current"]

# Parallel device (S_K) data import from EVO measurements
data_whole_EVO_gt = pd.read_csv("Chip 1/S_K/Gates/whole_device_gate_sweep_EVO.csv")
x_whole_EVO_gt = data_whole_EVO_gt["CH2 Voltage"]
y_whole_EVO_gt = data_whole_EVO_gt["CH1 Current"]

data_whole_EVO_5 = pd.read_csv("Chip 1/S_K/IVs/whole_device_5V_sweep_EVO.csv")
x_whole_EVO_5 = data_whole_EVO_5["CH1 Voltage"]
y_whole_EVO_5 = data_whole_EVO_5["CH1 Current"]

data_whole_EVO_35 = pd.read_csv("Chip 1/S_K/IVs/whole_device_35V_sweep_EVO.csv")
x_whole_EVO_35 = data_whole_EVO_35["CH1 Voltage"]
y_whole_EVO_35 = data_whole_EVO_35["CH1 Current"]

# %%
###data for ratio IVs tested in EVO at 35 Volt sweep after Nanofab irradiations
data_0001_EVO_NF = pd.read_csv("Chip 1/X_M/IVs/Nanofab_Feb_19/0001_35V_sweep_EVO_NF.csv")
x_0001_EVO_NF = data_0001_EVO_NF["CH1 Voltage"]
y_0001_EVO_NF = data_0001_EVO_NF["CH1 Current"]

#data_015_air = pd.read_csv("Chip 1/X_M/IVs/015_35V_sweep_air.csv")
#x_015_air = data["CH1 Voltage"]
#y_015_air = data["CH1 Current"]

data_02_EVO_NF = pd.read_csv("Chip 2/W_B/IVs/Nanofab_Feb_19/02_35V_sweep_EVO_NF.csv")
x_02_EVO_NF = data_02_EVO_NF["CH1 Voltage"]
y_02_EVO_NF = data_02_EVO_NF["CH1 Current"]

data_025_EVO_NF = pd.read_csv("Chip 1/X_M/IVs/Nanofab_Feb_19/025_35V_sweep_EVO_NF.csv")
x_025_EVO_NF= data_025_EVO_NF["CH1 Voltage"]
y_025_EVO_NF = data_025_EVO_NF["CH1 Current"]

data_03_EVO_NF = pd.read_csv("Chip 2/Z_A/IVs/Nanofab_Feb_19/03_35V_sweep_EVO_NF.csv")
x_03_EVO_NF = data_03_EVO_NF["CH1 Voltage"]
y_03_EVO_NF = data_03_EVO_NF["CH1 Current"]

#data_035_EVO = pd.read_csv("Chip 2/R_A/IVs/035_35V_sweep_EVO.csv")
#x_035_EVO = data_035_EVO["CH1 Voltage"]
#y_035_EVO = data_035_EVO["CH1 Current"]

data_04_EVO_NF = pd.read_csv("Chip 2/W_B/IVs/Nanofab_Feb_19/04_35V_sweep_EVO_NF.csv")
x_04_EVO_NF = data_04_EVO_NF["CH1 Voltage"]
y_04_EVO_NF = data_04_EVO_NF["CH1 Current"]

data_045_EVO_NF = pd.read_csv("Chip 2/R_A/IVs/Nanofab_Feb_19/045_35V_sweep_EVO_NF.csv")
x_045_EVO_NF = data_045_EVO_NF["CH1 Voltage"]
y_045_EVO_NF = data_045_EVO_NF["CH1 Current"]

data_05_EVO_NF = pd.read_csv("Chip 2/Z_A/IVs/Nanofab_Feb_19/05_35V_sweep_EVO_NF.csv")
x_05_EVO_NF = data_05_EVO_NF["CH1 Voltage"]
y_05_EVO_NF = data_05_EVO_NF["CH1 Current"]

data_055_EVO_NF = pd.read_csv("Chip 2/R_A/IVs/Nanofab_Feb_19/055_35V_sweep_EVO_NF.csv")
x_055_EVO_NF = data_055_EVO_NF["CH1 Voltage"]
y_055_EVO_NF = data_055_EVO_NF["CH1 Current"]

data_06_EVO_NF = pd.read_csv("Chip 1/V_K/IVs/Nanofab_Feb_19/06_35V_sweep_EVO_NF.csv")
x_06_EVO_NF = data_06_EVO_NF["CH1 Voltage"]
y_06_EVO_NF = data_06_EVO_NF["CH1 Current"]

data_065_EVO_NF = pd.read_csv("Chip 2/T_A/IVs/Nanofab_Feb_19/065_35V_sweep_EVO_NF.csv")
x_065_EVO_NF = data_065_EVO_NF["CH1 Voltage"]
y_065_EVO_NF = data_065_EVO_NF["CH1 Current"]

data_07_EVO_NF = pd.read_csv("Chip 1/V_K/IVs/Nanofab_Feb_19/07_35V_sweep_EVO_NF.csv")
x_07_EVO_NF = data_07_EVO_NF["CH1 Voltage"]
y_07_EVO_NF = data_07_EVO_NF["CH1 Current"]

data_075_EVO_NF = pd.read_csv("Chip 2/T_A/IVs/Nanofab_Feb_19/075_35V_sweep_EVO_NF.csv")
x_075_EVO_NF = data_075_EVO_NF["CH1 Voltage"]
y_075_EVO_NF = data_075_EVO_NF["CH1 Current"]

data_08_EVO_NF = pd.read_csv("Chip 1/V_K/IVs/Nanofab_Feb_19/08_35V_sweep_EVO_NF.csv")
x_08_EVO_NF = data_08_EVO_NF["CH1 Voltage"]
y_08_EVO_NF = data_08_EVO_NF["CH1 Current"]

data_085_EVO_NF = pd.read_csv("Chip 2/T_A/IVs/Nanofab_Feb_19/085_35V_sweep_EVO_NF.csv")
x_085_EVO_NF = data_085_EVO_NF["CH1 Voltage"]
y_085_EVO_NF = data_085_EVO_NF["CH1 Current"]

#data_09_air = pd.read_csv("Chip 1/W_L/IVs/09_35V_sweep_air.csv")
#x_09_air = data["CH1 Voltage"]
#y_09_air = data["CH1 Current"]

data_095_EVO_NF = pd.read_csv("Chip 2/W_B/IVs/Nanofab_Feb_19/095_35V_sweep_EVO_NF.csv")
x_095_EVO_NF = data_095_EVO_NF["CH1 Voltage"]
y_095_EVO_NF = data_095_EVO_NF["CH1 Current"]

data_10_EVO_NF = pd.read_csv("Chip 1/W_L/IVs/Nanofab_Feb_19/10_35V_sweep_EVO_NF.csv")
x_10_EVO_NF = data_10_EVO_NF["CH1 Voltage"]
y_10_EVO_NF = data_10_EVO_NF["CH1 Current"]

### Data for ratio IVs tested in EVO at 5 Volt sweep after Nanofab
data_0001_EVO_5_NF = pd.read_csv("Chip 2/W_B/IVs/Nanofab_Feb_19/02_5V_sweep_EVO_NF.csv")
x_0001_EVO_5_NF = data_0001_EVO_5_NF["CH1 Voltage"]
y_0001_EVO_5_NF = data_0001_EVO_5_NF["CH1 Current"]

#data_015_air = pd.read_csv("Chip 1/X_M/IVs/015_35V_sweep_air.csv")
#x_015_air = data["CH1 Voltage"]
#y_015_air = data["CH1 Current"]

data_02_EVO_5_NF = pd.read_csv("Chip 2/W_B/IVs/Nanofab_Feb_19/02_5V_sweep_EVO_NF.csv")
x_02_EVO_5_NF = data_02_EVO_5_NF["CH1 Voltage"]
y_02_EVO_5_NF = data_02_EVO_5_NF["CH1 Current"]

data_025_EVO_5_NF = pd.read_csv("Chip 1/X_M/IVs/Nanofab_Feb_19/025_5V_sweep_EVO_NF.csv")
x_025_EVO_5_NF = data_025_EVO_5_NF["CH1 Voltage"]
y_025_EVO_5_NF = data_025_EVO_5_NF["CH1 Current"]

data_03_EVO_5_NF = pd.read_csv("Chip 2/Z_A/IVs/Nanofab_Feb_19/03_5V_sweep_EVO_NF.csv")
x_03_EVO_5_NF = data_03_EVO_5_NF["CH1 Voltage"]
y_03_EVO_5_NF = data_03_EVO_5_NF["CH1 Current"]

#data_035_EVO_5 = pd.read_csv("Chip 2/R_A/IVs/035_5V_sweep_EVO.csv")
#x_035_EVO_5 = data_035_EVO_5["CH1 Voltage"]
#y_035_EVO_5 = data_035_EVO_5["CH1 Current"]

data_04_EVO_5_NF = pd.read_csv("Chip 2/W_B/IVs/Nanofab_Feb_19/04_5V_sweep_EVO_NF.csv")
x_04_EVO_5_NF = data_04_EVO_5_NF["CH1 Voltage"]
y_04_EVO_5_NF= data_04_EVO_5_NF["CH1 Current"]

data_045_EVO_5_NF = pd.read_csv("Chip 2/R_A/IVs/Nanofab_Feb_19/045_5V_sweep_EVO_NF.csv")
x_045_EVO_5_NF = data_045_EVO_5_NF["CH1 Voltage"]
y_045_EVO_5_NF = data_045_EVO_5_NF["CH1 Current"]

data_05_EVO_5_NF = pd.read_csv("Chip 2/Z_A/IVs/Nanofab_Feb_19/05_5V_sweep_EVO_NF.csv")
x_05_EVO_5_NF = data_05_EVO_5_NF["CH1 Voltage"]
y_05_EVO_5_NF = data_05_EVO_5_NF["CH1 Current"]

data_055_EVO_5_NF = pd.read_csv("Chip 2/R_A/IVs/Nanofab_Feb_19/055_5V_sweep_EVO_NF.csv")
x_055_EVO_5_NF = data_055_EVO_5_NF["CH1 Voltage"]
y_055_EVO_5_NF = data_055_EVO_5_NF["CH1 Current"]

data_06_EVO_5_NF = pd.read_csv("Chip 1/V_K/IVs/Nanofab_Feb_19/06_5V_sweep_EVO_NF.csv")
x_06_EVO_5_NF = data_06_EVO_5_NF["CH1 Voltage"]
y_06_EVO_5_NF = data_06_EVO_5_NF["CH1 Current"]

data_065_EVO_5_NF = pd.read_csv("Chip 2/T_A/IVs/Nanofab_Feb_19/065_5V_sweep_EVO_NF.csv")
x_065_EVO_5_NF = data_065_EVO_5_NF["CH1 Voltage"]
y_065_EVO_5_NF = data_065_EVO_5_NF["CH1 Current"]

data_07_EVO_5_NF = pd.read_csv("Chip 1/V_K/IVs/Nanofab_Feb_19/07_5V_sweep_EVO_NF.csv")
x_07_EVO_5_NF = data_07_EVO_5_NF["CH1 Voltage"]
y_07_EVO_5_NF = data_07_EVO_5_NF["CH1 Current"]

data_075_EVO_5_NF = pd.read_csv("Chip 2/T_A/IVs/Nanofab_Feb_19/075_5V_sweep_EVO_NF.csv")
x_075_EVO_5_NF = data_075_EVO_5_NF["CH1 Voltage"]
y_075_EVO_5_NF = data_075_EVO_5_NF["CH1 Current"]

data_08_EVO_5_NF = pd.read_csv("Chip 1/V_K/IVs/Nanofab_Feb_19/08_5V_sweep_EVO_NF.csv")
x_08_EVO_5_NF = data_08_EVO_5_NF["CH1 Voltage"]
y_08_EVO_5_NF = data_08_EVO_5_NF["CH1 Current"]

data_085_EVO_5_NF = pd.read_csv("Chip 2/T_A/IVs/Nanofab_Feb_19/085_5V_sweep_EVO_NF.csv")
x_085_EVO_5_NF = data_085_EVO_5_NF["CH1 Voltage"]
y_085_EVO_5_NF = data_085_EVO_5_NF["CH1 Current"]

#data_09_air = pd.read_csv("Chip 1/W_L/IVs/09_35V_sweep_air.csv")
#x_09_air = data["CH1 Voltage"]
#y_09_air = data["CH1 Current"]

data_095_EVO_5_NF = pd.read_csv("Chip 2/W_B/IVs/Nanofab_Feb_19/095_5V_sweep_EVO_NF.csv")
x_095_EVO_5_NF = data_095_EVO_5_NF["CH1 Voltage"]
y_095_EVO_5_NF = data_095_EVO_5_NF["CH1 Current"]

data_10_EVO_5_NF = pd.read_csv("Chip 1/W_L/IVs/Nanofab_Feb_19/10_5V_sweep_EVO_NF.csv")
x_10_EVO_5_NF = data_10_EVO_5_NF["CH1 Voltage"]
y_10_EVO_5_NF = data_10_EVO_5_NF["CH1 Current"]

### Data for ratio gate sweeps in EVO after Nanofab
data_0001_EVO_gt_NF = pd.read_csv("Chip 1/X_M/Gates/Nanofab_Feb_19/0001_gate_sweep_EVO_NF.csv")
x_0001_EVO_gt_NF = data_0001_EVO_gt_NF["CH2 Voltage"]
y_0001_EVO_gt_NF = data_0001_EVO_gt_NF["CH1 Current"]

#data_015_air_gt = pd.read_csv("Chip 1/X_M/Gates/015_gate_sweep_air.csv")
#x_015_air_gt = data["CH2 Voltage"]
#y_015_air_gt = data["CH1 Current"]

data_02_EVO_gt_NF = pd.read_csv("Chip 2/W_B/Gates/Nanofab_Feb_19/02_gate_sweep_EVO_NF.csv")
x_02_EVO_gt_NF = data_02_EVO_gt_NF["CH2 Voltage"]
y_02_EVO_gt_NF = data_02_EVO_gt_NF["CH1 Current"]

data_025_EVO_gt_NF = pd.read_csv("Chip 1/X_M/Gates/Nanofab_Feb_19/025_gate_sweep_EVO_NF.csv")
x_025_EVO_gt_NF = data_025_EVO_gt_NF["CH2 Voltage"]
y_025_EVO_gt_NF = data_025_EVO_gt_NF["CH1 Current"]

data_03_EVO_gt_NF = pd.read_csv("Chip 2/Z_A/Gates/Nanofab_Feb_19/03_gate_sweep_EVO_NF.csv")
x_03_EVO_gt_NF = data_03_EVO_gt_NF["CH2 Voltage"]
y_03_EVO_gt_NF = data_03_EVO_gt_NF["CH1 Current"]

#data_035_EVO_gt = pd.read_csv("Chip 2/R_A/Gates/035_gate_sweep_EVO.csv")
#x_035_EVO_gt = data_035_EVO_gt["CH2 Voltage"]
#y_035_EVO_gt = data_035_EVO_gt["CH1 Current"]

data_04_EVO_gt_NF = pd.read_csv("Chip 2/W_B/Gates/Nanofab_Feb_19/04_gate_sweep_EVO_NF.csv")
x_04_EVO_gt_NF = data_04_EVO_gt_NF["CH2 Voltage"]
y_04_EVO_gt_NF = data_04_EVO_gt_NF["CH1 Current"]

data_045_EVO_gt_NF = pd.read_csv("Chip 2/R_A/Gates/Nanofab_Feb_19/045_gate_sweep_EVO_NF.csv")
x_045_EVO_gt_NF = data_045_EVO_gt_NF["CH2 Voltage"]
y_045_EVO_gt_NF = data_045_EVO_gt_NF["CH1 Current"]

data_05_EVO_gt_NF = pd.read_csv("Chip 2/Z_A/Gates/Nanofab_Feb_19/05_gate_sweep_EVO_NF.csv")
x_05_EVO_gt_NF = data_05_EVO_gt_NF["CH2 Voltage"]
y_05_EVO_gt_NF = data_05_EVO_gt_NF["CH1 Current"]

data_055_EVO_gt_NF = pd.read_csv("Chip 2/R_A/Gates/Nanofab_Feb_19/055_gate_sweep_EVO_NF.csv")
x_055_EVO_gt_NF = data_055_EVO_gt_NF ["CH2 Voltage"]
y_055_EVO_gt_NF = data_055_EVO_gt_NF ["CH1 Current"]

data_06_EVO_gt_NF = pd.read_csv("Chip 1/V_K/Gates/Nanofab_Feb_19/06_gate_sweep_EVO_NF.csv")
x_06_EVO_gt_NF = data_06_EVO_gt_NF["CH2 Voltage"]
y_06_EVO_gt_NF = data_06_EVO_gt_NF["CH1 Current"]

data_065_EVO_gt_NF = pd.read_csv("Chip 2/T_A/Gates/Nanofab_Feb_19/065_gate_sweep_EVO_NF.csv")
x_065_EVO_gt_NF = data_065_EVO_gt_NF["CH2 Voltage"]
y_065_EVO_gt_NF = data_065_EVO_gt_NF["CH1 Current"]

data_07_EVO_gt_NF = pd.read_csv("Chip 1/V_K/Gates/Nanofab_Feb_19/07_gate_sweep_EVO_NF.csv")
x_07_EVO_gt_NF = data_07_EVO_gt_NF["CH2 Voltage"]
y_07_EVO_gt_NF = data_07_EVO_gt_NF["CH1 Current"]

data_075_EVO_gt_NF = pd.read_csv("Chip 2/T_A/Gates/Nanofab_Feb_19/075_gate_sweep_EVO_NF.csv")
x_075_EVO_gt_NF = data_075_EVO_gt_NF["CH2 Voltage"]
y_075_EVO_gt_NF = data_075_EVO_gt_NF["CH1 Current"]

data_08_EVO_gt_NF = pd.read_csv("Chip 1/V_K/Gates/Nanofab_Feb_19/08_gate_sweep_EVO_NF.csv")
x_08_EVO_gt_NF = data_08_EVO_gt_NF["CH2 Voltage"]
y_08_EVO_gt_NF = data_08_EVO_gt_NF["CH1 Current"]

data_085_EVO_gt_NF = pd.read_csv("Chip 2/T_A/Gates/Nanofab_Feb_19/085_gate_sweep_EVO_NF.csv")
x_085_EVO_gt_NF = data_085_EVO_gt_NF["CH2 Voltage"]
y_085_EVO_gt_NF = data_085_EVO_gt_NF["CH1 Current"]

#data_09_air_gt = pd.read_csv("Chip 1/W_L/Gates/09_gate_sweep_air.csv")
#x_09_air_gt = data["CH2 Voltage"]
#y_09_air_gt = data["CH1 Current"]

data_095_EVO_gt_NF = pd.read_csv("Chip 2/W_B/Gates/Nanofab_Feb_19/095_gate_sweep_EVO_NF.csv")
x_095_EVO_gt_NF = data_095_EVO_gt_NF["CH2 Voltage"]
y_095_EVO_gt_NF = data_095_EVO_gt_NF["CH1 Current"]

data_10_EVO_gt_NF = pd.read_csv("Chip 1/W_L/Gates/Nanofab_Feb_19/10_gate_sweep_EVO_NF.csv")
x_10_EVO_gt_NF = data_10_EVO_gt_NF["CH2 Voltage"]
y_10_EVO_gt_NF = data_10_EVO_gt_NF["CH1 Current"]

# Parallel device (S_K) data import from EVO measurements
data_whole_EVO_gt_NF = pd.read_csv("Chip 1/S_K/Gates/Nanofab_Feb_19/whole_device_gate_sweep_EVO_NF.csv")
x_whole_EVO_gt_NF = data_whole_EVO_gt_NF["CH2 Voltage"]
y_whole_EVO_gt_NF = data_whole_EVO_gt_NF["CH1 Current"]

data_whole_EVO_5_NF = pd.read_csv("Chip 1/S_K/IVs/Nanofab_Feb_19/whole_device_5V_sweep_EVO_NF.csv")
x_whole_EVO_5_NF = data_whole_EVO_5_NF["CH1 Voltage"]
y_whole_EVO_5_NF = data_whole_EVO_5_NF["CH1 Current"]

data_whole_EVO_35_NF = pd.read_csv("Chip 1/S_K/IVs/Nanofab_Feb_19/whole_device_35V_sweep_EVO_NF.csv")
x_whole_EVO_35_NF = data_whole_EVO_35_NF["CH1 Voltage"]
y_whole_EVO_35_NF = data_whole_EVO_35_NF["CH1 Current"]

# %%
r_048 = y_06_EVO_gt_NF/y_06_EVO_gt
print(r_048[0])
print(r_048[199])
print(max(r_048))
print(min(r_048))
# Out:
# 1.4850615114235501
# 0.00022625052010981196
# 12.214285714285714
# -0.8285714285714284

# %%
r_076 = y_07_EVO_gt_NF/y_07_EVO_gt
print(r_076[0])
print(r_076[199])
print(max(r_076))
print(min(r_076))
# Out:
# 2.3365122615803817
# 8.236859910924733e-05
# 57.4
# -70.66666666666667

# %%
r_06 = y_08_EVO_gt_NF/y_08_EVO_gt
print(r_06[0])
print(r_06[199])
print(max(r_06))
print(min(r_06))
# Out:
# 2.033559508527416
# 0.00010092981098256478
# 36.857142857142854
# -10.891891891891893

# %%
r_018 = y_10_EVO_gt_NF/y_10_EVO_gt
print(r_018[0])
print(r_018[199])
print(max(r_018))
print(min(r_018))
# Out:
# 188.2242305813385
# 1.5781243363996975
# 391546.87500000006
# -554956.0

# %%
r_018_2 = y_0001_EVO_gt_NF/y_0001_EVO_gt
print(r_018_2[0])
print(r_018_2[199])
print(max(r_018_2))
print(min(r_018_2))
# Out:
# 830.0441176470588
# 21.029742516517416
# inf
# -9956990.0

# %%
r_004 = y_025_EVO_gt_NF/y_025_EVO_gt
print(r_004[0])
print(r_004[199])
print(max(r_004))
print(min(r_004))
# Out:
# 1.8733741392501915
# 1.1771355083254367
# 754.9145299145299
# 1.0261011419249593

# %%
r_0 = y_045_EVO_gt_NF/y_045_EVO_gt
print(r_0[0])
print(r_0[199])
print(max(r_0))
print(min(r_0))
# Out:
# 1.0686383928571428
# 0.22734226302557786
# 118.33333333333334
# -8.272727272727273

# %%
r_038 = y_055_EVO_gt_NF/y_055_EVO_gt
print(r_038[0])
print(r_038[199])
print(max(r_038))
print(min(r_038))
# Out:
# 0.91768393269548
# 0.39788633240310606
# 1877.7333333333333
# -7815.333333333333

# %%
r_007 = y_085_EVO_gt_NF/y_085_EVO_gt
print(r_007[0])
print(r_007[199])
print(max(r_007))
print(min(r_007))
# Out:
# 4852.304079835632
# 2.3000426362528064
# 224527.09497206705
# 2.3000426362528064

# %%
r_018_3 = y_075_EVO_gt_NF/y_075_EVO_gt
print(r_018_3[0])
print(r_018_3[199])
print(max(r_018_3))
print(min(r_018_3))
# Out:
# 2.162797531589774
# 0.053849513031097015
# 2.596912521440823
# -1.1974448369402522e-05

# %%
r_037 = y_065_EVO_gt_NF/y_065_EVO_gt
print(r_037[0])
print(r_037[199])
print(max(r_037))
print(min(r_037))
# Out:
# 1.3857142857142857
# 0.0006229606862576037
# 1.3857142857142857
# -0.00019343775486731216

# %%
r_032 = y_04_EVO_gt_NF/y_04_EVO_gt
print(r_032[0])
print(r_032[199])
print(max(r_032))
print(min(r_032))
# Out:
# 14.43131378049
# 0.08619227910032329
# 28.512283527990338
# 0.07743010309553564

# %%
r_002 = y_02_EVO_gt_NF/y_02_EVO_gt
print(r_002[0])
print(r_002[199])
print(max(r_002))
print(min(r_002))
# Out:
# 0.9583908596113373
# 0.3606467333772745
# 0.9583908596113373
# 0.0022128881638713337

# %%
r_028 = y_095_EVO_gt_NF/y_095_EVO_gt
print(r_028[0])
print(r_028[199])
print(max(r_028))
print(min(r_028))
# Out:
# 1.24227322268592
# 0.09132644669541669
# 1.24227322268592
# 0.08517916137229986

# %%
r_041 = y_03_EVO_gt_NF/y_03_EVO_gt
print(r_041[0])
print(r_041[199])
print(max(r_041))
print(min(r_041))
# Out:
# 0.7968145079127894
# 0.2200496416153919
# 1.7793263904276535
# 0.21180901020413065

# %%
r_058 = y_05_EVO_gt_NF/y_05_EVO_gt
print(r_058[0])
print(r_058[199])
print(max(r_058))
print(min(r_058))
# Out:
# 0.7641742877573295
# 0.054265501133272546
# 1.5353181171414465
# 0.054186440677966095

# %%
#Linear fit to data
fit_evo = np.polyfit(x_06_EVO_gt[100:], y_06_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_06_EVO_gt_NF[100:], y_06_EVO_gt_NF[100:], 1)
fit_evo_1 = np.poly1d(fit_evo)
fit_nf_1 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_07_EVO_gt[100:], y_07_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_07_EVO_gt_NF[100:], y_07_EVO_gt_NF[100:], 1)
fit_evo_2 = np.poly1d(fit_evo)
fit_nf_2 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_08_EVO_gt[100:], y_08_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_08_EVO_gt_NF[100:], y_08_EVO_gt_NF[100:], 1)
fit_evo_3 = np.poly1d(fit_evo)
fit_nf_3 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_10_EVO_gt[100:], y_10_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_10_EVO_gt_NF[100:], y_10_EVO_gt_NF[100:], 1)
fit_evo_4 = np.poly1d(fit_evo)
fit_nf_4 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_0001_EVO_gt[100:], y_0001_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_0001_EVO_gt_NF[100:], y_0001_EVO_gt_NF[100:], 1)
fit_evo_5 = np.poly1d(fit_evo)
fit_nf_5 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_025_EVO_gt[100:], y_025_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_025_EVO_gt_NF[100:], y_025_EVO_gt_NF[100:], 1)
fit_evo_6 = np.poly1d(fit_evo)
fit_nf_6 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_045_EVO_gt[100:], y_045_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_045_EVO_gt_NF[100:], y_045_EVO_gt_NF[100:], 1)
fit_evo_7 = np.poly1d(fit_evo)
fit_nf_7 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_055_EVO_gt[100:], y_055_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_055_EVO_gt_NF[100:], y_055_EVO_gt_NF[100:], 1)
fit_evo_8 = np.poly1d(fit_evo)
fit_nf_8 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_085_EVO_gt[100:], y_085_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_085_EVO_gt_NF[100:], y_085_EVO_gt_NF[100:], 1)
fit_evo_9 = np.poly1d(fit_evo)
fit_nf_9 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_075_EVO_gt[60:100], y_075_EVO_gt[60:100], 1)
fit_nf = np.polyfit(x_075_EVO_gt_NF[100:], y_075_EVO_gt_NF[100:], 1)
fit_evo_10 = np.poly1d(fit_evo)
fit_nf_10 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_065_EVO_gt[100:], y_065_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_065_EVO_gt_NF[100:], y_065_EVO_gt_NF[100:], 1)
fit_evo_11 = np.poly1d(fit_evo)
fit_nf_11 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_04_EVO_gt[60:100], y_04_EVO_gt[60:100], 1)
fit_nf = np.polyfit(x_04_EVO_gt_NF[0:40], y_04_EVO_gt_NF[0:40], 1)
fit_evo_12 = np.poly1d(fit_evo)
fit_nf_12 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_02_EVO_gt[50:80], y_02_EVO_gt[50:80], 1)
fit_nf = np.polyfit(x_02_EVO_gt_NF[60:100], y_02_EVO_gt_NF[60:100], 1)
fit_evo_13 = np.poly1d(fit_evo)
fit_nf_13 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_095_EVO_gt[60:100], y_095_EVO_gt[60:100], 1)
fit_nf = np.polyfit(x_095_EVO_gt_NF[0:40], y_095_EVO_gt_NF[0:40], 1)
fit_evo_14 = np.poly1d(fit_evo)
fit_nf_14 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_03_EVO_gt[60:100], y_03_EVO_gt[60:100], 1)
fit_nf = np.polyfit(x_03_EVO_gt_NF[60:100], y_03_EVO_gt_NF[60:100], 1)
fit_evo_15 = np.poly1d(fit_evo)
fit_nf_15 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))

#Linear fit to data
fit_evo = np.polyfit(x_055_EVO_gt[100:], y_055_EVO_gt[100:], 1)
fit_nf = np.polyfit(x_055_EVO_gt_NF[100:], y_055_EVO_gt_NF[100:], 1)
fit_evo_16 = np.poly1d(fit_evo)
fit_nf_16 = np.poly1d(fit_nf)
#Threshold values are where fitted line intercepts x-axis
t_evo = -fit_evo[1]/fit_evo[0]
t_nf = -fit_nf[1]/fit_nf[0]
print((t_evo-t_nf))
# Out:
# -15.838944589698349
# -13.60460768556374
# -29.807089485790364
# 24.57870992016589
# 20.230314179602555
# 8.944592057196484
# -5.923564989376726
# 2.968186183308349
# 35.51421433191166
# -27.215886845240213
# -4.129079258029419
# 24.65925411224881
# -21.87259129828064
# 26.628812275496983
# 5.9854927939614235
# 2.968186183308349

# %%
fig = plt.figure(figsize = (16,16))
sns.set_style('ticks')
ax1 = fig.add_subplot(441)

ax1.set_title("Ratio = 0.48", fontsize = 15)
ax1.plot(x_06_EVO_gt, y_06_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax1.plot(x_06_EVO_gt_NF, y_06_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax1.plot(x_06_EVO_gt_NF, r_048, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax1.set_xlabel("Gate bias (V)", fontsize = 12)
ax1.set_ylabel("Current (A)", fontsize = 12)
ax1.legend(loc = 'lower right')

ax2 = fig.add_subplot(442)

ax2.set_title("Ratio = 0.76", fontsize = 15)
ax2.plot(x_07_EVO_gt, y_07_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax2.plot(x_07_EVO_gt_NF, y_07_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax2.plot(x_07_EVO_gt_NF, r_076, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax2.set_yscale('log')
ax2.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax2.set_xlabel("Gate bias (V)", fontsize = 12)
ax2.set_ylabel("Current (A)", fontsize = 12)
ax2.legend(loc = 'lower right')

ax3 = fig.add_subplot(443)

ax3.set_title("Ratio = 0.6", fontsize = 15)
ax3.plot(x_08_EVO_gt, y_08_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax3.plot(x_08_EVO_gt_NF, y_08_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax3.plot(x_08_EVO_gt_NF, r_06, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax3.set_yscale('log')
ax3.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax3.set_xlabel("Gate bias (V)", fontsize = 12)
ax3.set_ylabel("Current (A)", fontsize = 12)
ax3.legend(loc = 'lower right')

ax4 = fig.add_subplot(444)

ax4.set_title("Ratio = 0.18", fontsize = 15)
ax4.plot(x_10_EVO_gt, y_10_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax4.plot(x_10_EVO_gt_NF, y_10_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax4.plot(x_10_EVO_gt_NF, r_018, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax4.set_yscale('log')
ax4.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax4.set_xlabel("Gate bias (V)", fontsize = 12)
ax4.set_ylabel("Current (A)", fontsize = 12)
ax4.legend(loc = 'lower right')

ax5 = fig.add_subplot(445)

ax5.set_title("Ratio = 0.18 no. 2", fontsize = 15)
ax5.plot(x_0001_EVO_gt, y_0001_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax5.plot(x_0001_EVO_gt_NF, y_0001_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax5.plot(x_0001_EVO_gt_NF, r_018_2, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax5.set_yscale('log')
ax5.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax5.set_xlabel("Gate bias (V)", fontsize = 12)
ax5.set_ylabel("Current (A)", fontsize = 12)
ax5.legend(loc = 'lower right')

ax6 = fig.add_subplot(446)

ax6.set_title("Ratio = 0.04", fontsize = 15)
ax6.plot(x_025_EVO_gt, y_025_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax6.plot(x_025_EVO_gt_NF, y_025_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax6.plot(x_025_EVO_gt_NF, r_004, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax6.set_yscale('log')
ax6.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax6.set_xlabel("Gate bias (V)", fontsize = 12)
ax6.set_ylabel("Current (A)", fontsize = 12)
ax6.legend(loc = 'lower right')

ax7 = fig.add_subplot(447)

ax7.set_title("Ratio = 0", fontsize = 15)
ax7.plot(x_045_EVO_gt, y_045_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax7.plot(x_045_EVO_gt_NF, y_045_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax7.plot(x_045_EVO_gt_NF, r_0, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax7.set_yscale('log')
ax7.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax7.set_xlabel("Gate bias (V)", fontsize = 12)
ax7.set_ylabel("Current (A)", fontsize = 12)
ax7.legend(loc = 'lower right')

ax8 = fig.add_subplot(448)

ax8.set_title("Ratio = 0.38", fontsize = 15)
ax8.plot(x_055_EVO_gt, y_055_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax8.plot(x_055_EVO_gt_NF, y_055_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax8.plot(x_055_EVO_gt_NF, r_038, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax8.set_yscale('log')
ax8.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax8.set_xlabel("Gate bias (V)", fontsize = 12)
ax8.set_ylabel("Current (A)", fontsize = 12)
ax8.legend(loc = 'lower right')

ax9 = fig.add_subplot(449)

ax9.set_title("Ratio = 0.07", fontsize = 15)
ax9.plot(x_085_EVO_gt, y_085_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax9.plot(x_085_EVO_gt_NF, y_085_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax9.plot(x_085_EVO_gt_NF, r_007, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax9.set_yscale('log')
ax9.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax9.set_xlabel("Gate bias (V)", fontsize = 12)
ax9.set_ylabel("Current (A)", fontsize = 12)
ax9.legend(loc = 'lower right')

ax10 = fig.add_subplot(4,4,10)

ax10.set_title("Ratio = 0.18 no. 3", fontsize = 15)
ax10.plot(x_075_EVO_gt, y_075_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax10.plot(x_075_EVO_gt_NF, y_075_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax10.plot(x_075_EVO_gt_NF, r_018_3, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax10.set_yscale('log')
ax10.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax10.set_xlabel("Gate bias (V)", fontsize = 12)
ax10.set_ylabel("Current (A)", fontsize = 12)
ax10.legend(loc = 'lower right')

ax11 = fig.add_subplot(4,4,11)

ax11.set_title("Ratio = 0.37", fontsize = 15)
ax11.plot(x_065_EVO_gt, y_065_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax11.plot(x_065_EVO_gt_NF, y_065_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax11.plot(x_065_EVO_gt_NF, r_037, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax11.set_yscale('log')
ax11.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax11.set_xlabel("Gate bias (V)", fontsize = 12)
ax11.set_ylabel("Current (A)", fontsize = 12)
ax11.legend(loc = 'lower right')

ax12 = fig.add_subplot(4,4,12)

ax12.set_title("Ratio = 0.32", fontsize = 15)
ax12.plot(x_04_EVO_gt, y_04_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax12.plot(x_04_EVO_gt_NF, y_04_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax12.plot(x_04_EVO_gt_NF, r_032, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax12.set_yscale('log')
ax12.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax12.set_xlabel("Gate bias (V)", fontsize = 12)
ax12.set_ylabel("Current (A)", fontsize = 12)
ax12.legend(loc = 'lower right')

ax13 = fig.add_subplot(4,4,13)

ax13.set_title("Ratio = 0.02", fontsize = 15)
ax13.plot(x_02_EVO_gt, y_02_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax13.plot(x_02_EVO_gt_NF, y_02_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax13.plot(x_02_EVO_gt_NF, r_002, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax13.set_yscale('log')
ax13.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax13.set_xlabel("Gate bias (V)", fontsize = 12)
ax13.set_ylabel("Current (A)", fontsize = 12)
ax13.legend(loc = 'lower right')

ax14 = fig.add_subplot(4,4,14)

ax14.set_title("Ratio = 0.28", fontsize = 15)
ax14.plot(x_095_EVO_gt, y_095_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax14.plot(x_095_EVO_gt_NF, y_095_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax14.plot(x_095_EVO_gt_NF, r_028, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax14.set_yscale('log')
ax14.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax14.set_xlabel("Gate bias (V)", fontsize = 12)
ax14.set_ylabel("Current (A)", fontsize = 12)
ax14.legend(loc = 'lower right')

ax15 = fig.add_subplot(4,4,15)

ax15.set_title("Ratio = 0.41", fontsize = 15)
ax15.plot(x_03_EVO_gt, y_03_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax15.plot(x_03_EVO_gt_NF, y_03_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax15.plot(x_03_EVO_gt_NF, r_041, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax15.set_yscale('log')
ax15.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax15.set_xlabel("Gate bias (V)", fontsize = 12)
ax15.set_ylabel("Current (A)", fontsize = 12)
ax15.legend(loc = 'lower right')

ax16 = fig.add_subplot(4,4,16)

ax16.set_title("Ratio = 0.58", fontsize = 15)
ax16.plot(x_055_EVO_gt, y_055_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax16.plot(x_055_EVO_gt_NF, y_055_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax16.plot(x_055_EVO_gt_NF, r_058, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "b",
        label = "Ratio")
ax16.set_yscale('log')
ax16.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax16.set_xlabel("Gate bias (V)", fontsize = 12)
ax16.set_ylabel("Current (A)", fontsize = 12)
ax16.legend(loc = 'lower right')

plt.tight_layout()
plt.savefig("Gate_quotients",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize = (16,16))
sns.set_style('ticks')
ax1 = fig.add_subplot(441)

ax1.set_title("Ratio = 0.48", fontsize = 15)
ax1.plot(x_06_EVO_gt, y_06_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax1.plot(x_06_EVO_gt_NF, y_06_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax1.plot(x_06_EVO_gt, fit_evo_1(x_06_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax1.plot(x_06_EVO_gt_NF, fit_nf_1(x_06_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax1.set_yscale('log')
ax1.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax1.set_xlabel("Gate bias (V)", fontsize = 12)
ax1.set_ylabel("Current (A)", fontsize = 12)
ax1.legend(loc = 'lower right')

ax2 = fig.add_subplot(442)

ax2.set_title("Ratio = 0.76", fontsize = 15)
ax2.plot(x_07_EVO_gt, y_07_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax2.plot(x_07_EVO_gt_NF, y_07_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax2.plot(x_07_EVO_gt, fit_evo_2(x_07_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax2.plot(x_07_EVO_gt_NF, fit_nf_2(x_07_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax2.set_yscale('log')
ax2.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax2.set_xlabel("Gate bias (V)", fontsize = 12)
ax2.set_ylabel("Current (A)", fontsize = 12)
ax2.legend(loc = 'lower right')

ax3 = fig.add_subplot(443)

ax3.set_title("Ratio = 0.6", fontsize = 15)
ax3.plot(x_08_EVO_gt, y_08_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax3.plot(x_08_EVO_gt_NF, y_08_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax3.plot(x_08_EVO_gt, fit_evo_3(x_08_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax3.plot(x_08_EVO_gt_NF, fit_nf_3(x_08_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax3.set_yscale('log')
ax3.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax3.set_xlabel("Gate bias (V)", fontsize = 12)
ax3.set_ylabel("Current (A)", fontsize = 12)
ax3.legend(loc = 'lower right')

ax4 = fig.add_subplot(444)

ax4.set_title("Ratio = 0.18", fontsize = 15)
ax4.plot(x_10_EVO_gt, y_10_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax4.plot(x_10_EVO_gt_NF, y_10_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax4.plot(x_10_EVO_gt, fit_evo_4(x_10_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax4.plot(x_10_EVO_gt_NF, fit_nf_4(x_10_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax4.set_yscale('log')
ax4.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax4.set_xlabel("Gate bias (V)", fontsize = 12)
ax4.set_ylabel("Current (A)", fontsize = 12)
ax4.legend(loc = 'lower right')

ax5 = fig.add_subplot(445)

ax5.set_title("Ratio = 0.18 no. 2", fontsize = 15)
ax5.plot(x_0001_EVO_gt, y_0001_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax5.plot(x_0001_EVO_gt_NF, y_0001_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax5.plot(x_0001_EVO_gt, fit_evo_5(x_0001_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax5.plot(x_0001_EVO_gt_NF, fit_nf_5(x_0001_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax5.set_yscale('log')
ax5.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax5.set_xlabel("Gate bias (V)", fontsize = 12)
ax5.set_ylabel("Current (A)", fontsize = 12)
ax5.legend(loc = 'lower right')

ax6 = fig.add_subplot(446)

ax6.set_title("Ratio = 0.04", fontsize = 15)
ax6.plot(x_025_EVO_gt, y_025_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax6.plot(x_025_EVO_gt_NF, y_025_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax6.plot(x_025_EVO_gt, fit_evo_6(x_025_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax6.plot(x_025_EVO_gt_NF, fit_nf_6(x_025_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax6.set_yscale('log')
ax6.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax6.set_xlabel("Gate bias (V)", fontsize = 12)
ax6.set_ylabel("Current (A)", fontsize = 12)
ax6.legend(loc = 'lower right')

ax7 = fig.add_subplot(447)

ax7.set_title("Ratio = 0", fontsize = 15)
ax7.plot(x_045_EVO_gt, y_045_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax7.plot(x_045_EVO_gt_NF, y_045_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax7.plot(x_045_EVO_gt, fit_evo_7(x_045_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax7.plot(x_045_EVO_gt_NF, fit_nf_7(x_045_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax7.set_yscale('log')
ax7.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax7.set_xlabel("Gate bias (V)", fontsize = 12)
ax7.set_ylabel("Current (A)", fontsize = 12)
ax7.legend(loc = 'lower right')

ax8 = fig.add_subplot(448)

ax8.set_title("Ratio = 0.38", fontsize = 15)
ax8.plot(x_055_EVO_gt, y_055_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax8.plot(x_055_EVO_gt_NF, y_055_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax8.plot(x_055_EVO_gt, fit_evo_8(x_055_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax8.plot(x_055_EVO_gt_NF, fit_nf_8(x_055_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax8.set_yscale('log')
ax8.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax8.set_xlabel("Gate bias (V)", fontsize = 12)
ax8.set_ylabel("Current (A)", fontsize = 12)
ax8.legend(loc = 'lower right')

ax9 = fig.add_subplot(449)

ax9.set_title("Ratio = 0.07", fontsize = 15)
ax9.plot(x_085_EVO_gt, y_085_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax9.plot(x_085_EVO_gt_NF, y_085_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax9.plot(x_085_EVO_gt, fit_evo_9(x_085_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax9.plot(x_085_EVO_gt_NF, fit_nf_9(x_085_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax9.set_yscale('log')
ax9.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax9.set_xlabel("Gate bias (V)", fontsize = 12)
ax9.set_ylabel("Current (A)", fontsize = 12)
ax9.legend(loc = 'lower right')

ax10 = fig.add_subplot(4,4,10)

ax10.set_title("Ratio = 0.18 no. 3", fontsize = 15)
ax10.plot(x_075_EVO_gt, y_075_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax10.plot(x_075_EVO_gt_NF, y_075_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax10.plot(x_075_EVO_gt, fit_evo_10(x_075_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax10.plot(x_075_EVO_gt_NF, fit_nf_10(x_075_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax10.set_yscale('log')
ax10.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax10.set_xlabel("Gate bias (V)", fontsize = 12)
ax10.set_ylabel("Current (A)", fontsize = 12)
ax10.legend(loc = 'lower right')

ax11 = fig.add_subplot(4,4,11)

ax11.set_title("Ratio = 0.37", fontsize = 15)
ax11.plot(x_065_EVO_gt, y_065_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax11.plot(x_065_EVO_gt_NF, y_065_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax11.plot(x_065_EVO_gt, fit_evo_11(x_065_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax11.plot(x_065_EVO_gt_NF, fit_nf_11(x_065_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax11.set_yscale('log')
ax11.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax11.set_xlabel("Gate bias (V)", fontsize = 12)
ax11.set_ylabel("Current (A)", fontsize = 12)
ax11.legend(loc = 'lower right')

ax12 = fig.add_subplot(4,4,12)

ax12.set_title("Ratio = 0.32", fontsize = 15)
ax12.plot(x_04_EVO_gt, y_04_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax12.plot(x_04_EVO_gt_NF, y_04_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax12.plot(x_04_EVO_gt, fit_evo_12(x_04_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax12.plot(x_04_EVO_gt_NF, fit_nf_12(x_04_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax12.set_yscale('log')
ax12.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax12.set_xlabel("Gate bias (V)", fontsize = 12)
ax12.set_ylabel("Current (A)", fontsize = 12)
ax12.legend(loc = 'lower right')

ax13 = fig.add_subplot(4,4,13)

ax13.set_title("Ratio = 0.02", fontsize = 15)
ax13.plot(x_02_EVO_gt, y_02_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax13.plot(x_02_EVO_gt_NF, y_02_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax13.plot(x_02_EVO_gt, fit_evo_13(x_02_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax13.plot(x_02_EVO_gt_NF, fit_nf_13(x_02_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax13.set_yscale('log')
ax13.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax13.set_xlabel("Gate bias (V)", fontsize = 12)
ax13.set_ylabel("Current (A)", fontsize = 12)
ax13.legend(loc = 'lower right')

ax14 = fig.add_subplot(4,4,14)

ax14.set_title("Ratio = 0.28", fontsize = 15)
ax14.plot(x_095_EVO_gt, y_095_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax14.plot(x_095_EVO_gt_NF, y_095_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax14.plot(x_095_EVO_gt, fit_evo_14(x_095_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax14.plot(x_095_EVO_gt_NF, fit_nf_14(x_095_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax14.set_yscale('log')
ax14.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax14.set_xlabel("Gate bias (V)", fontsize = 12)
ax14.set_ylabel("Current (A)", fontsize = 12)
ax14.legend(loc = 'lower right')

ax15 = fig.add_subplot(4,4,15)

ax15.set_title("Ratio = 0.41", fontsize = 15)
ax15.plot(x_03_EVO_gt, y_03_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax15.plot(x_03_EVO_gt_NF, y_03_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax15.plot(x_03_EVO_gt, fit_evo_15(x_03_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax15.plot(x_03_EVO_gt_NF, fit_nf_15(x_03_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax15.set_yscale('log')
ax15.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax15.set_xlabel("Gate bias (V)", fontsize = 12)
ax15.set_ylabel("Current (A)", fontsize = 12)
ax15.legend(loc = 'lower right')

ax16 = fig.add_subplot(4,4,16)

ax16.set_title("Ratio = 0.58", fontsize = 15)
ax16.plot(x_055_EVO_gt, y_055_EVO_gt, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax16.plot(x_055_EVO_gt_NF, y_055_EVO_gt_NF, 'o', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax16.plot(x_055_EVO_gt, fit_evo_16(x_055_EVO_gt), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax16.plot(x_055_EVO_gt_NF, fit_nf_16(x_055_EVO_gt_NF), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")
ax16.set_yscale('log')
ax16.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax16.set_xlabel("Gate bias (V)", fontsize = 12)
ax16.set_ylabel("Current (A)", fontsize = 12)
ax16.legend(loc = 'lower right')

plt.tight_layout()
plt.savefig("Thresholds",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize = (8,8))
sns.set_style('ticks')
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.set_title("Ratio at - 60", fontsize = 15)
ax2.set_title("Saturation ratio", fontsize = 15)
ax3.set_title("Max. ratio", fontsize = 15)
ax4.set_title("Min. ratio", fontsize = 15)

ax1.plot(true_ratio, ratio_60, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax2.plot(true_ratio, sat_ratio, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax3.plot(true_ratio, max_ratio, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "gold",
        label = "Ratio")
ax4.plot(true_ratio, min_ratio, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "indigo",
        label = "Ratio")


ax1.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax2.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax3.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax4.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')

ax1.set_xlabel("Cut-to-channel ratio", fontsize = 12)
ax1.set_ylabel("Ratio", fontsize = 12)
ax2.set_xlabel("Cut-to-channel ratio", fontsize = 12)
ax2.set_ylabel("Ratio", fontsize = 12)
ax3.set_xlabel("Cut-to-channel ratio", fontsize = 12)
ax3.set_ylabel("Ratio", fontsize = 12)
ax4.set_xlabel("Cut-to-channel ratio", fontsize = 12)
ax4.set_ylabel("Ratio", fontsize = 12)

ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')
#ax16.legend(loc = 'lower right')

plt.tight_layout()
plt.savefig("As fnxn",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize = (8,8))
sns.set_style('ticks')
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

ax1.set_title("Ratio at - 60", fontsize = 15)
ax2.set_title("Saturation ratio", fontsize = 15)
ax3.set_title("Max. ratio", fontsize = 15)
ax4.set_title("Min. ratio", fontsize = 15)

ax1.plot(elec_ratio, ratio_60, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax2.plot(elec_ratio, sat_ratio, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")
ax3.plot(elec_ratio, max_ratio, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "gold",
        label = "Ratio")
ax4.plot(elec_ratio, min_ratio, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "indigo",
        label = "Ratio")


ax1.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax2.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax3.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax4.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')

ax1.set_xlabel("Electrode ratio", fontsize = 12)
ax1.set_ylabel("Ratio", fontsize = 12)
ax2.set_xlabel("Electrode ratio", fontsize = 12)
ax2.set_ylabel("Ratio", fontsize = 12)
ax3.set_xlabel("Electrode ratio", fontsize = 12)
ax3.set_ylabel("Ratio", fontsize = 12)
ax4.set_xlabel("Electrode ratio", fontsize = 12)
ax4.set_ylabel("Ratio", fontsize = 12)

ax1.set_yscale('log')
ax2.set_yscale('log')
ax3.set_yscale('log')
ax4.set_yscale('log')
#ax16.legend(loc = 'lower right')

plt.tight_layout()
plt.savefig("As fnxn of elec ratio",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize = (8,4))
sns.set_style('ticks')
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)


fit_elec = np.polyfit(elec_ratio, Vth, 1)
fit_eleco = np.poly1d(fit_elec)




ax1.plot(elec_ratio,Vth, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "g",
        label = "EVO")
ax2.plot(true_ratio, Vth, 'o', ms =10,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "r",
        label = "NF")



ax1.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')
ax2.tick_params(which = 'both', direction = 'in', top = 'on', right = 'on')


ax1.set_xlabel("Electrode ratio", fontsize = 12)
ax1.set_ylabel("$\Delta V_{th}$", fontsize = 12)
ax2.set_xlabel("Cut-to-channel ratio", fontsize = 12)
ax2.set_ylabel("$\Delta V_{th}$", fontsize = 12)


ax1.plot(elec_ratio, fit_eleco(elec_ratio), '-', ms =5,alpha = 0.9, mew = '0.5', color = 'black', linewidth = 2, mfc = "black",
       label = "NF")



plt.tight_layout()
plt.savefig("Thresholds as fnxn of ratio",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize = (4,4))
sns.set_style('ticks')
sns.kdeplot(true_ratio,  shade = True, c = 'dodgerblue')
# Out:
# C:\Users\Jakub\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2400: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))

# %%
g = sns.PairGrid(data, palette="Set2",
                 hue_kws={"marker": ["o", "s", "D"]})
g = g.map(plt.scatter, linewidths=1, edgecolor="w", s=40)
g = g.add_legend()
plt.savefig("pairwise_all",bbox_inches='tight', dpi = 300)
# Out:
# C:\Users\Jakub\Anaconda3\lib\site-packages\matplotlib\legend.py:590: UserWarning: The handle <matplotlib.patches.Patch object at 0x0000020F6D99A668> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   'legend.'.format(handle, label))

# %%
sns.pairplot(vars=["Electrode ratio","True ratio", "Delta Vth", "Positive Vset",
                   "Negative Vset", "Positive HRS/LRS", "Negative HRS/LRS"], 
             data=data.dropna(), size=7)
plt.savefig("pairwise_selects",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
fig.canvas.draw()
sns.set_style('ticks')

scale_y = 1e-6
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax1.yaxis.set_major_formatter(ticks_y)


ax1 = fig.add_subplot(1,4,1)
ax1.plot(x_02_EVO_NF, abs(y_02_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax1.plot(x_02_EVO, abs(y_02_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax1.yaxis.set_major_formatter(ticks_y)
ax1.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 16)
ax1.set_title('Ratio = 0.017')
ax1.set_xlim([-35,0])

ax2 = fig.add_subplot(1,4,2)
ax2.plot(x_02_EVO_NF, abs(y_02_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax2.plot(x_02_EVO, abs(y_02_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax2.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax2.set_title('Ratio = 0.017')
ax2.set_xlim([0,35])
#ax3.set_ylim([20*10e-7,50*10e-7])
ax2.legend(loc = 'lower right')
plt.setp(ax2.get_yticklabels(), visible=False)

ax3 = fig.add_subplot(1,4,3)
ax3.plot(x_0001_EVO_NF, abs(y_0001_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax3.plot(x_0001_EVO, abs(y_0001_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax3.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax3.set_title('Ratio = 0.18 no. 2')
ax3.set_xlim([-35,0])
plt.setp(ax3.get_yticklabels(), visible=False)

ax4 = fig.add_subplot(1,4,4)
ax4.plot(x_0001_EVO_NF, abs(y_0001_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax4.plot(x_0001_EVO, abs(y_0001_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax4.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax4.set_title('Ratio = 0.18 no. 2')
ax4.set_xlim([0,35])
#ax3.set_ylim([20*10e-7,50*10e-7])
ax4.legend(loc = 'upper right')
plt.setp(ax4.get_yticklabels(), visible=False)
plt.tight_layout()
plt.savefig("Vsets_1_2",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
fig.canvas.draw()
sns.set_style('ticks')

scale_y = 1e-6
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax1.yaxis.set_major_formatter(ticks_y)


ax1 = fig.add_subplot(1,4,1)
ax1.plot(x_025_EVO_NF, abs(y_025_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax1.plot(x_025_EVO, abs(y_025_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax1.yaxis.set_major_formatter(ticks_y)
ax1.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 16)
ax1.set_title('Ratio = 0.04')
ax1.set_xlim([-35,0])

ax2 = fig.add_subplot(1,4,2)
ax2.plot(x_025_EVO_NF, abs(y_025_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax2.plot(x_025_EVO, abs(y_025_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax2.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax2.set_title('Ratio = 0.04')
ax2.set_xlim([0,35])
ax2.set_ylim([0,8*10e-7])
ax2.legend(loc = 'upper right')
plt.setp(ax2.get_yticklabels(), visible=True)

ax3 = fig.add_subplot(1,4,3)
ax3.plot(x_045_EVO_NF, abs(y_045_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax3.plot(x_045_EVO, abs(y_045_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
#ax3.plot(x_045_EVO_NF, fit_lrs_1(x_045_EVO_NF),'-', ms=5, color = 'black',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'EVO' )
ax3.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax3.set_title('Ratio = 0')
ax3.set_xlim([-35,0])
ax3.set_ylim([0,2*10e-7])
plt.setp(ax3.get_yticklabels(), visible=True)

ax4 = fig.add_subplot(1,4,4)
ax4.plot(x_045_EVO_NF, abs(y_045_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax4.plot(x_045_EVO, abs(y_045_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax4.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax4.set_title('Ratio = 0')
ax4.set_xlim([0,35])
ax4.set_ylim([0,0.005*10e-7])
ax4.legend(loc = 'upper right')
#plt.setp(ax4.get_yticklabels(), visible=True)
plt.tight_layout()
plt.savefig("Vsets_3_4",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
fig.canvas.draw()
sns.set_style('ticks')

scale_y = 1e-6
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)


ax1 = fig.add_subplot(1,4,1)
ax1.plot(x_03_EVO_NF, abs(y_03_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
#ax1.plot(x_03_EVO_NF[151:168], abs(y_03_EVO_NF[151:168]), '-', ms=2, color = 'r',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'NF' )
ax1.plot(x_03_EVO, abs(y_03_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax1.yaxis.set_major_formatter(ticks_y)
ax1.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 16)
ax1.set_title('Ratio = 0.41')
ax1.set_xlim([-35,0])
ax1.set_ylim([0,3*10e-7])
ax1.legend(loc = 'upper right')

ax2 = fig.add_subplot(1,4,2)
ax2.plot(x_03_EVO_NF, abs(y_03_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax2.plot(x_03_EVO, abs(y_03_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax2.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax2.set_title('Ratio = 0.41')
ax2.set_xlim([0,35])
ax2.set_ylim([0,30*10e-7])

plt.setp(ax2.get_yticklabels(), visible=True)

ax3 = fig.add_subplot(1,4,3)
ax3.plot(x_06_EVO_NF, abs(y_06_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax3.plot(x_06_EVO, abs(y_06_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
#ax3.plot(x_045_EVO_NF, fit_lrs_1(x_045_EVO_NF),'-', ms=5, color = 'black',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'EVO' )
ax3.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax3.set_title('Ratio = 0.48')
ax3.set_xlim([-35,0])
ax3.set_ylim([0,0.025*10e-7])
plt.setp(ax3.get_yticklabels(), visible=True)

ax4 = fig.add_subplot(1,4,4)
ax4.plot(x_06_EVO_NF, abs(y_06_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax4.plot(x_06_EVO, abs(y_06_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax4.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax4.set_title('Ratio = 0.48')
ax4.set_xlim([0,35])
ax4.set_ylim([0,0.002*10e-7])
ax4.legend(loc = 'upper right')
#plt.setp(ax4.get_yticklabels(), visible=True)
plt.tight_layout()
plt.savefig("Vsets_5_6",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
fig.canvas.draw()
sns.set_style('ticks')

scale_y = 1e-6
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)


ax1 = fig.add_subplot(1,4,1)
ax1.plot(x_04_EVO_NF, abs(y_04_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )

ax1.plot(x_04_EVO, abs(y_04_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax1.yaxis.set_major_formatter(ticks_y)
ax1.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 16)
ax1.set_title('Ratio = 0.32')
ax1.set_xlim([-35,0])
ax1.set_ylim([0,60*10e-7])
ax1.legend(loc = 'upper right')

ax2 = fig.add_subplot(1,4,2)
ax2.plot(x_04_EVO_NF, abs(y_04_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax2.plot(x_04_EVO, abs(y_04_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax2.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax2.set_title('Ratio = 0.32')
ax2.set_xlim([0,35])
ax2.set_ylim([0,40*10e-7])


plt.setp(ax2.get_yticklabels(), visible=True)

ax3 = fig.add_subplot(1,4,3)
ax3.plot(x_085_EVO_NF, abs(y_085_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax3.plot(x_085_EVO, abs(y_085_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
#ax3.plot(x_045_EVO_NF, fit_lrs_1(x_045_EVO_NF),'-', ms=5, color = 'black',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'EVO' )
ax3.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax3.set_title('Ratio = 0.07')
ax3.set_xlim([-10,0])
#ax3.set_ylim([0,0.025*10e-7])
plt.setp(ax3.get_yticklabels(), visible=True)

ax4 = fig.add_subplot(1,4,4)
ax4.plot(x_085_EVO_NF, abs(y_085_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax4.plot(x_085_EVO, abs(y_085_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax4.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax4.set_title('Ratio = 0.07')
ax4.set_xlim([0,10])
#ax4.set_ylim([0,0.002*10e-7])
ax4.legend(loc = 'upper left')
#plt.setp(ax4.get_yticklabels(), visible=True)

#ax3.plot(x_085_EVO_NF[100:106], abs(y_085_EVO_NF[100:106]), '-', ms=2, color = 'r',  lw=3, alpha=0.7,
#mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'NF' )

plt.tight_layout()
plt.savefig("Vsets_7_8",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
fig.canvas.draw()
sns.set_style('ticks')

scale_y = 1e-6
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)


ax1 = fig.add_subplot(1,4,1)
ax1.plot(x_07_EVO_NF, abs(y_07_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )

ax1.plot(x_07_EVO, abs(y_07_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax1.yaxis.set_major_formatter(ticks_y)
ax1.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 16)
ax1.set_title('Ratio = 0.76')
ax1.set_xlim([-35,0])
ax1.set_ylim([0,0.03*10e-7])
ax1.legend(loc = 'upper right')

ax2 = fig.add_subplot(1,4,2)
ax2.plot(x_07_EVO_NF, abs(y_07_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax2.plot(x_07_EVO, abs(y_07_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax2.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax2.set_title('Ratio = 0.76')
ax2.set_xlim([0,35])
ax2.set_ylim([0,0.004*10e-7])


plt.setp(ax2.get_yticklabels(), visible=True)

ax3 = fig.add_subplot(1,4,3)
ax3.plot(x_05_EVO_NF, abs(y_05_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax3.plot(x_05_EVO, abs(y_05_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
#ax3.plot(x_045_EVO_NF, fit_lrs_1(x_045_EVO_NF),'-', ms=5, color = 'black',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'EVO' )
ax3.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax3.set_title('Ratio = 0.58')
ax3.set_xlim([-35,0])
ax3.set_ylim([0,20*10e-7])
plt.setp(ax3.get_yticklabels(), visible=True)

ax4 = fig.add_subplot(1,4,4)
ax4.plot(x_05_EVO_NF, abs(y_05_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax4.plot(x_05_EVO, abs(y_05_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax4.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax4.set_title('Ratio = 0.58')
ax4.set_xlim([0,35])
ax4.set_ylim([0,0.05*10e-7])
ax4.legend(loc = 'upper left')
#plt.setp(ax4.get_yticklabels(), visible=True)

#ax4.plot(x_05_EVO_NF[50:85], abs(y_05_EVO_NF[50:85]), '-', ms=2, color = 'r',  lw=3, alpha=0.7,
#mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'NF' )

plt.tight_layout()
plt.savefig("Vsets_9_10",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
fig.canvas.draw()
sns.set_style('ticks')

scale_y = 1e-6
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)


ax1 = fig.add_subplot(1,4,1)
ax1.plot(x_075_EVO_NF, abs(y_075_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )

ax1.plot(x_075_EVO, abs(y_075_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax1.yaxis.set_major_formatter(ticks_y)
ax1.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 16)
ax1.set_title('Ratio = 0.18 no. 3')
ax1.set_xlim([-35,0])
ax1.set_ylim([0,3*10e-7])
ax1.legend(loc = 'upper right')

ax2 = fig.add_subplot(1,4,2)
ax2.plot(x_075_EVO_NF, abs(y_075_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax2.plot(x_075_EVO, abs(y_075_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax2.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax2.set_title('Ratio = 0.18 no. 3')
ax2.set_xlim([0,35])
ax2.set_ylim([0,0.003*10e-7])


plt.setp(ax2.get_yticklabels(), visible=True)

ax3 = fig.add_subplot(1,4,3)
ax3.plot(x_08_EVO_NF, abs(y_08_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax3.plot(x_08_EVO, abs(y_08_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
#ax3.plot(x_045_EVO_NF, fit_lrs_1(x_045_EVO_NF),'-', ms=5, color = 'black',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'EVO' )
ax3.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax3.set_title('Ratio = 0.6')
ax3.set_xlim([-35,0])
ax3.set_ylim([0,0.3*10e-7])
plt.setp(ax3.get_yticklabels(), visible=True)

ax4 = fig.add_subplot(1,4,4)
ax4.plot(x_08_EVO_NF, abs(y_08_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax4.plot(x_08_EVO, abs(y_08_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax4.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax4.set_title('Ratio = 0.6')
ax4.set_xlim([0,35])
ax4.set_ylim([0,0.002*10e-7])
ax4.legend(loc = 'upper left')
#plt.setp(ax4.get_yticklabels(), visible=True)

#ax1.plot(x_075_EVO_NF[150:175], abs(y_075_EVO_NF[150:175]), '-', ms=2, color = 'r',  lw=3, alpha=0.7,
#mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'NF' )

plt.tight_layout()
plt.savefig("Vsets_11_12",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
fig.canvas.draw()
sns.set_style('ticks')

scale_y = 1e-6
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)


ax1 = fig.add_subplot(1,4,1)
ax1.plot(x_055_EVO_NF, abs(y_055_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )

ax1.plot(x_055_EVO, abs(y_055_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax1.yaxis.set_major_formatter(ticks_y)
ax1.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 16)
ax1.set_title('Ratio =0.38')
ax1.set_xlim([-35,0])
#ax1.set_ylim([0,3*10e-7])
ax1.legend(loc = 'upper right')

ax2 = fig.add_subplot(1,4,2)
ax2.plot(x_055_EVO_NF, abs(y_055_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax2.plot(x_055_EVO, abs(y_055_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax2.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax2.set_title('Ratio = 0.38')
ax2.set_xlim([0,35])
ax2.set_ylim([0,0.08*10e-7])


plt.setp(ax2.get_yticklabels(), visible=True)

ax3 = fig.add_subplot(1,4,3)
ax3.plot(x_065_EVO_NF, abs(y_065_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax3.plot(x_065_EVO, abs(y_065_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
#ax3.plot(x_045_EVO_NF, fit_lrs_1(x_045_EVO_NF),'-', ms=5, color = 'black',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'EVO' )
ax3.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax3.set_title('Ratio = 0.37')
ax3.set_xlim([-35,0])
ax3.set_ylim([0,0.1*10e-7])
plt.setp(ax3.get_yticklabels(), visible=True)

ax4 = fig.add_subplot(1,4,4)
ax4.plot(x_065_EVO_NF, abs(y_065_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax4.plot(x_065_EVO, abs(y_065_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax4.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax4.set_title('Ratio = 0.37')
ax4.set_xlim([0,35])
ax4.set_ylim([0,0.0002*10e-7])
ax4.legend(loc = 'upper left')
#plt.setp(ax4.get_yticklabels(), visible=True)

#ax4.plot(x_065_EVO_NF[0:9], abs(y_065_EVO_NF[0:9]), '-', ms=2, color = 'r',  lw=3, alpha=0.7,
#mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'NF' )

plt.tight_layout()
plt.savefig("Vsets_13_14",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
fig.canvas.draw()
sns.set_style('ticks')

scale_y = 1e-6
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)


ax1 = fig.add_subplot(1,4,1)
ax1.plot(x_095_EVO_NF, abs(y_095_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )

ax1.plot(x_095_EVO, abs(y_095_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax1.yaxis.set_major_formatter(ticks_y)
ax1.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 16)
ax1.set_title('Ratio =0.28')
ax1.set_xlim([-35,0])
#ax1.set_ylim([0,3*10e-7])
ax1.legend(loc = 'upper right')

ax2 = fig.add_subplot(1,4,2)
ax2.plot(x_095_EVO_NF, abs(y_095_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax2.plot(x_095_EVO, abs(y_095_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax2.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax2.set_title('Ratio = 0.28')
ax2.set_xlim([0,35])
#ax2.set_ylim([0,0.08*10e-7])


plt.setp(ax2.get_yticklabels(), visible=True)

ax3 = fig.add_subplot(1,4,3)
ax3.plot(x_10_EVO_NF, abs(y_10_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax3.plot(x_10_EVO, abs(y_10_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
#ax3.plot(x_045_EVO_NF, fit_lrs_1(x_045_EVO_NF),'-', ms=5, color = 'black',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'EVO' )
ax3.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax3.set_title('Ratio = 0.18 no. 1')
ax3.set_xlim([-35,0])
#ax3.set_ylim([0,0.1*10e-7])
plt.setp(ax3.get_yticklabels(), visible=True)

ax4 = fig.add_subplot(1,4,4)
ax4.plot(x_10_EVO_NF, abs(y_10_EVO_NF), '-', ms=2, color = 'mediumblue',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'NF' )
ax4.plot(x_10_EVO, abs(y_10_EVO),'-', ms=5, color = 'forestgreen',  lw=3, alpha=0.7, mfc='orange', dash_capstyle = 'butt',
mew = '1', label = 'EVO' )
ax4.yaxis.set_major_formatter(ticks_y)
#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax4.set_title('Ratio = 0.18 no. 1')
ax4.set_xlim([0,35])
#ax4.set_ylim([0,0.0002*10e-7])
ax4.legend(loc = 'upper left')
#plt.setp(ax4.get_yticklabels(), visible=True)

#ax4.plot(x_10_EVO_NF[0:22], abs(y_10_EVO_NF[0:22]), '-', ms=2, color = 'r',  lw=3, alpha=0.7,
#mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'NF' )

plt.tight_layout()
plt.savefig("Vsets_15_16",bbox_inches='tight', dpi = 300)
plt.show()

# %%
print(x_10_EVO_NF[22])

# %%
linregress(x_10_EVO_NF[0:22], y_10_EVO_NF[0:22])

# %%
linregress(x_10_EVO_NF[22:49], y_10_EVO_NF[22:49])

# %%
2.231525290667097e-06/5.117855398569683e-07

# %%
1/0.6983402595837511

# %%
fit_lrs = np.polyfit(x_045_EVO_NF[120:150], abs(y_045_EVO_NF[120:150]), 1)
fit_hrs = np.polyfit(x_045_EVO_NF[150:180], abs(y_045_EVO_NF[150:180]), 1)
fit_lrs_1 = np.poly1d(fit_lrs)
fit_hrs_1 = np.poly1d(fit_hrs)

# %%
fig = plt.figure(figsize=(8,8))
fig.canvas.draw()
sns.set_style('ticks')


ax1 = fig.add_subplot(2,2,1)
ax1.plot(elec_ratio, pos_states, 's', ms=8, color = 'mediumblue',  lw=3, alpha=0.7, mfc='mediumblue', dash_capstyle = 'butt',
mew = '1', label = 'NF' )



#ax1.set_ylabel('I$_{DS}$ ($\mu$A)', fontsize = 16)
ax1.set_title('Positive states vs true ratio')
#ax1.set_xlim([-35,0])
#ax1.set_ylim([0,3*10e-7])
ax1.legend(loc = 'upper right')

ax2 = fig.add_subplot(2,2,2)
ax2.plot(elec_ratio, neg_states, 's', ms=8, color = 'mediumblue',  lw=3, alpha=0.7, mfc='mediumblue', dash_capstyle = 'butt',
mew = '1', label = 'NF' )

#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax2.set_title('Negative states vs true ratio')
#ax2.set_xlim([0,35])
#ax2.set_ylim([0,0.08*10e-7])


plt.setp(ax2.get_yticklabels(), visible=True)

ax3 = fig.add_subplot(2,2,3)
ax3.plot(elec_ratio, pos_vset, 's', ms=8, color = 'mediumblue',  lw=3, alpha=0.7, mfc='mediumblue', dash_capstyle = 'butt',
mew = '1', label = 'NF' )

#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax3.set_title('pos V_set vs true ratio')
#ax3.set_xlim([-35,0])
#ax3.set_ylim([0,0.1*10e-7])
plt.setp(ax3.get_yticklabels(), visible=True)

ax4 = fig.add_subplot(2,2,4)
ax4.plot(elec_ratio, neg_vset, 's', ms=8, color = 'mediumblue',  lw=3, alpha=0.7, mfc='mediumblue', dash_capstyle = 'butt',
mew = '1', label = 'NF' )

#ax3.set_ylabel('I$_{DS}$ (A)', fontsize = 16)
ax4.set_title('Neg vset vs true ratio')
#ax4.set_xlim([0,35])
#ax4.set_ylim([0,0.0002*10e-7])
#ax4.legend(loc = 'upper left')
#plt.setp(ax4.get_yticklabels(), visible=True)

#ax4.plot(x_10_EVO_NF[0:22], abs(y_10_EVO_NF[0:22]), '-', ms=2, color = 'r',  lw=3, alpha=0.7,
#mfc='orange', dash_capstyle = 'butt',
#mew = '1', label = 'NF' )

plt.tight_layout()
plt.savefig("True_ratio_states",bbox_inches='tight', dpi = 300)
plt.show()

# %%
fig = plt.figure(figsize=(8,8))
fig.canvas.draw()


ax1 = fig.add_subplot(2,2,1)

x = np.mean(pos_vset.dropna())
s = np.std(pos_vset.dropna())
print(x,s)

# best fit of data
(mu, sigma) = norm.fit(pos_vset.dropna())

# the histogram of the data
n, bins, patches = plt.hist(pos_vset.dropna(), 16, normed=1, facecolor='forestgreen',edgecolor = 'black', alpha=0.95)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, '-',c = 'black', linewidth=3)

#plot
plt.xlabel('V$_{set}$ (V)', fontsize = 14)
plt.ylabel('Frequency', fontsize = 14)
plt.title('Positive V$_{set}$', fontsize = 14)
plt.grid(True)


ax2 = fig.add_subplot(2,2,2)

x = np.mean(neg_vset.dropna())
s = np.std(neg_vset.dropna())
print(x,s)

# best fit of data
(mu, sigma) = norm.fit(neg_vset.dropna())

# the histogram of the data
n, bins, patches = plt.hist(neg_vset.dropna(), 16, normed=1, facecolor='dodgerblue',edgecolor = 'black', alpha=0.95)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, '-',c = 'black', linewidth=3)

#plot
plt.xlabel('V$_{set}$ (V)', fontsize = 14)
plt.ylabel('Frequency', fontsize = 14)
plt.title('Negative V$_{set}$', fontsize = 14)
plt.grid(True)

ax3 = fig.add_subplot(2,2,3)

x = np.mean(pos_states.dropna())
s = np.std(pos_states.dropna())
print(x,s)

# best fit of data
(mu, sigma) = norm.fit(pos_states.dropna())

# the histogram of the data
n, bins, patches = plt.hist(pos_states.dropna(), 16, normed=1, facecolor='tomato',edgecolor = 'black', alpha=0.95)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, '-',c = 'black', linewidth=3)

#plot
plt.xlabel('Ratio', fontsize = 14)
plt.ylabel('Frequency', fontsize = 14)
plt.title('Positive R$_{off}$/R$_{on}$ ', fontsize = 14)
plt.grid(True)

ax4 = fig.add_subplot(2,2,4)

x = np.mean(neg_states.dropna())
s = np.std(neg_states.dropna())
print(x,s)

# best fit of data
(mu, sigma) = norm.fit(neg_states.dropna())

# the histogram of the data
n, bins, patches = plt.hist(neg_states.dropna(), 16, normed=1, facecolor='gold', edgecolor = 'black', alpha=0.95)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, '-',c = 'black', linewidth=3)

#plot
plt.xlabel('Ratio', fontsize = 14)
plt.ylabel('Frequency', fontsize = 14)
plt.title('Negative R$_{off}$/R$_{on}$ ', fontsize = 14)
plt.grid(True)


plt.tight_layout()
plt.savefig("States_distributions",bbox_inches='tight', dpi = 300)
plt.show()
# Out:
# 13.104166666666666 6.030493979674375
# -18.900000000000002 7.555461600723016
# 9.736249999999998 19.04195528136488
# 7.08625 8.524788028889633

# %% [markdown]
# # R<sub>Pearson</sub> analyses

# %%
r_p = pd.read_csv("R_pearson.csv")
r_p.head()
# Out:
#    True ratio  Electrode ratio  Delta Vth  Positive Vset  Negative Vset  \
# 0        1.00            -0.09      -0.31           0.06          -0.60
# 1       -0.09             1.00       0.25           0.11          -0.43
# 2       -0.31             0.25       1.00            NaN            NaN
# 3        0.06             0.11        NaN           1.00          -0.58
# 4       -0.60            -0.43        NaN          -0.58           1.00
#
#    Positive HRS/LRS  Negative HRS/LRS  Ratio at - 60  Saturation ratio  \
# 0             -0.27            -0.210      -0.304480         -0.200614
# 1              0.45             0.075      -0.230815          0.210385
# 2              0.11             0.056       0.488243          0.295263
# 3             -0.41             0.470            NaN               NaN
# 4               NaN            -0.630            NaN               NaN
#
#    Max ratio  Min ratio  Small electrode  True area of cut
# 0  -0.303987   0.156090        -0.008011          0.617842
# 1  -0.389403  -0.237685         0.435669          0.104574
# 2   0.537572  -0.253405        -0.055383         -0.115622
# 3        NaN        NaN              NaN               NaN
# 4        NaN        NaN              NaN               NaN

# %%
fig, ax = plt.subplots(1,1, figsize=(7,7))

heatplot = ax.imshow(r_p, cmap='PiYG',interpolation='nearest')

tick_spacing = 1
ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax.set_title("Heatmap of R Pearson coefficients between variables")

labels = [item.get_text() for item in ax.get_xticklabels()]
labels[1] = 'True ratio'
labels[2] = 'Electrode ratio'
labels[3] = '$\Delta$ V$_{th}$ ratio'
labels[4] = '+ve V$_{set}$'
labels[5] = '-ve V$_{set}$'
labels[6] = 'Positive state ratio'
labels[7] = 'Negative state ratio'
labels[8] = 'Ratio at -60 V'
labels[9] = 'Ratio at 60 V'
labels[10] = 'Maximum gate ratio'
labels[11] = 'Minimum gate ratio'
labels[12] = 'Small electrode width'
labels[13] = 'True area of cut'
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)

for tick in ax.get_xticklabels():
    tick.set_rotation(30)

cbaxes = fig.add_axes([1.0, 0.11, 0.03, 0.8]) 
cb = plt.colorbar(heatplot, cax = cbaxes)  
plt.savefig("R_Pearson_heatmap",bbox_inches='tight', dpi = 300)
plt.show()

# %%
a2 = sp.stats.pearsonr(true_cut, true_ratio)
a3 = sp.stats.pearsonr(true_cut, elec_ratio)
a7 = sp.stats.pearsonr(true_cut, Vth)
a8 = sp.stats.pearsonr(true_cut, pos_vset)
a9 = sp.stats.pearsonr(true_cut, neg_vset)
a10 = sp.stats.pearsonr(true_cut, pos_states)
a11 = sp.stats.pearsonr(true_cut, neg_states)
a1 = sp.stats.pearsonr(true_cut, ratio_60)
a4 = sp.stats.pearsonr(true_cut, sat_ratio)
a5 = sp.stats.pearsonr(true_cut, max_ratio)
a6 = sp.stats.pearsonr(true_cut, min_ratio)

print(a2[0])
print(a3[0])
print(a7[0])
print(a8[0])
print(a9[0])
print(a10[0])
print(a11[0])
print(a1[0])
print(a4[0])
print(a5[0])
print(a6[0])
# Out:
# 0.6178417502979998
# 0.10457387448054352
# -0.11562180294685112
# nan
# nan
# -0.11895297471633495
# -0.08413314047535729
# -0.26264039230125824
# -0.253900794892801
# -0.33700924812567934
# 0.2057710958415962
# C:\Users\Jakub\Anaconda3\lib\site-packages\scipy\stats\stats.py:5240: RuntimeWarning: invalid value encountered in less
#   x = np.where(x < 1.0, x, 1.0)  # if x > 1 then return 1.0

# %%
data = pd.read_csv("Ratio_parameters.csv")
sample = data["Sample"]
true_channel = data["True area of channel"]
true_cut = data["True area of cut"]
true_ratio = data["True ratio"]
large_elec = data["Large electrode width"]
small_elec = data["Small electrode width"]
elec_ratio = data["Electrode ratio"]
overshoot = data["Overshoot"]
elec_cut = data["Electrode cut"]
GBs = data["GBs"]
ratio_60 = data["Ratio at -60"]
sat_ratio = data["Saturation ratio"]
max_ratio = data["Max ratio"]
min_ratio = data["Min ratio"]
Vth = data["Delta Vth"]
pos_vset = data["Positive Vset"]
neg_vset = data["Negative Vset"]
pos_states = data["Positive HRS/LRS"]
neg_states = data["Negative HRS/LRS"]
